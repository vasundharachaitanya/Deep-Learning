# %%
#importing required libraries
import numpy as np
import random as rd 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading csv file
df = pd.read_csv("iris_modified.csv") 
df.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    100 non-null    int64
#  1   sepal_length  100 non-null    float64
#  2   sepal_width   100 non-null    float64
#  3   petal_length  100 non-null    float64
#  4   petal_width   100 non-null    float64
#  5   species       100 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
df
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0            0           5.1          3.5           1.4          0.2
# 1            1           4.9          3.0           1.4          0.2
# 2            2           4.7          3.2           1.3          0.2
# 3            3           4.6          3.1           1.5          0.2
# 4            4           5.0          3.6           1.4          0.2
# ..         ...           ...          ...           ...          ...
# 95          95           5.7          3.0           4.2          1.2
# 96          96           5.7          2.9           4.2          1.3
# 97          97           6.2          2.9           4.3          1.3
# 98          98           5.1          2.5           3.0          1.1
# 99          99           5.7          2.8           4.1          1.3
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 95  versicolor
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [raw]
# -- There are no null values in the given dataset.

# %% [markdown]
# ## EDA

# %% [markdown]
# # Analysing Features-Univariate
# ##### Non Viz
# - Min
# - Max
# - Central Tendency
# - Percentiles
# - Dispersion
#
# ##### Viz
# - Plot of Dist- Distribution
# - Plot of box plot - Outlier

# %%
# Non-vizualisation statistical analysis for sepal_length column
print("min of sepal_length:",df["sepal_length"].min())
print("max of sepal_length:",df["sepal_length"].max())
print("mean of sepal_length:",df["sepal_length"].mean())
print("median of sepal_length:",df["sepal_length"].median())                                       
print("standard deviation of sepal_length:",df["sepal_length"].std())
# Out:
# min of sepal_length: 4.3
# max of sepal_length: 7.0
# mean of sepal_length: 5.471000000000001
# median of sepal_length: 5.4
# standard deviation of sepal_length: 0.6416983463254117

# %%
# plotting the distribution for sepal_length column
df["sepal_length"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# detecting outliers in sepal_length column using box column
df["sepal_length"].plot(kind="box")
# Out:
# <Axes: >

# %%
# Non-vizualisation statistical analysis for sepal_width column
print("min of sepal_width:",df["sepal_width"].min())
print("max of sepal_width:",df["sepal_width"].max())
print("mean of sepal_width:",df["sepal_width"].mean())
print("median of sepal_width:",df["sepal_width"].median())                                       
print("standard deviation of sepal_width:",df["sepal_width"].std())
# Out:
# min of sepal_width: 2.0
# max of sepal_width: 4.4
# mean of sepal_width: 3.0989999999999998
# median of sepal_width: 3.05
# standard deviation of sepal_width: 0.47873887359489514

# %%
# plotting the distribution for sepal_width column
df["sepal_width"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# detecting outliers in sepal_width column using box column
df["sepal_width"].plot(kind="box")
# Out:
# <Axes: >

# %%
# Removing outliers using IQR method
q3 = df["sepal_width"].quantile(0.75)
q1 = df["sepal_width"].quantile(0.25)
iqr = q3-q1
lower = q1-1.5*(iqr)
upper = q3+1.5*(iqr)

# %%
df= df[(df["sepal_width"]>lower) & (df["sepal_width"]<upper)]

# %%
# detecting outliers in sepal_width column using box column
df["sepal_width"].plot(kind="box")
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    99 non-null     int64
#  1   sepal_length  99 non-null     float64
#  2   sepal_width   99 non-null     float64
#  3   petal_length  99 non-null     float64
#  4   petal_width   99 non-null     float64
#  5   species       99 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 5.4+ KB

# %%
# Non-vizualisation statistical analysis for petal_length column
print("min of petal_length:",df["petal_length"].min())
print("max of petal_length:",df["petal_length"].max())
print("mean of petal_length:",df["petal_length"].mean())
print("median of petal_length:",df["petal_length"].median())                                       
print("standard deviation of petal_length:",df["petal_length"].std())
# Out:
# min of petal_length: 1.0
# max of petal_length: 5.1
# mean of petal_length: 2.874747474747475
# median of petal_length: 3.0
# standard deviation of petal_length: 1.4503583958444963

# %%
# plotting the distribution for petal_length column
df["petal_length"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# detecting outliers in petal_length column using box column
df["petal_length"].plot(kind="box")
# Out:
# <Axes: >

# %%
# Non-vizualisation statistical analysis for petal_width column
print("min of petal_width:",df["petal_width"].min())
print("max of petal_width:",df["petal_width"].max())
print("mean of petal_width:",df["petal_width"].mean())
print("median of petal_width:",df["petal_width"].median())                                       
print("standard deviation of petal_width:",df["petal_width"].std())
# Out:
# min of petal_width: 0.1
# max of petal_width: 1.8
# mean of petal_width: 0.7898989898989898
# median of petal_width: 1.0
# standard deviation of petal_width: 0.5666757611405974

# %%
# detecting outliers in petal_length column using box column
df["petal_width"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.scatterplot(data=df, x='sepal_length', y='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.scatterplot(data=df, x='sepal_width', y='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.scatterplot(data=df, x='petal_length', y='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.scatterplot(data=df, x='petal_width', y='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>

# %%
sns.heatmap(df[["sepal_length","sepal_width","petal_length","petal_width"]].corr(),annot=True)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.pairplot(df,hue = 'species')

# %% [markdown]
# ## Observation:
# - From the above plot, we can see that 'petal_length' and 'petal_width' are the two characteristics that can effectively tell us whether an iris flower belongs to the 'setosa' or 'versicolor' species. In simpler terms, just by looking at the length and width of the petals, we can confidently determine the species of the iris flower without needing to consider other features. These two features are the most important for classifying iris flowers.

# %%
df = df[["petal_length","petal_width","species"]]

# %%
df
# Out:
#     petal_length  petal_width     species
# 0            1.4          0.2      setosa
# 1            1.4          0.2      setosa
# 2            1.3          0.2      setosa
# 3            1.5          0.2      setosa
# 4            1.4          0.2      setosa
# ..           ...          ...         ...
# 95           4.2          1.2  versicolor
# 96           4.2          1.3  versicolor
# 97           4.3          1.3  versicolor
# 98           3.0          1.1  versicolor
# 99           4.1          1.3  versicolor
#
# [99 rows x 3 columns]

# %% [markdown]
# ## Implementation of Perceptronic Trick

# %%
import random as rd

# %%
df['species'] = df['species'].apply(lambda x: 1 if x == "setosa" else 0)

# %%
learning_rate = 0.01
w0 = 1
w1 = np.random.random()
w2 = np.random.random()
W = [w1,w2,w0]


for _ in range(1500):
    for i in range(len(df)):
        index = np.random.choice(df.index)

        x = df.loc[index, ["petal_length", "petal_width"]].values
        y = df.loc[index, "species"]
        
        # dot product between weights and inputs 
        z = np.dot(W[:2], x) + W[2]

        pred_label = 1 if z>0 else 0
        # checking for correctly classified points
        if pred_label != y:

            elif z<0 and y==1:
                W[:2] += learning_rate * x
                W[2] += learning_rate
            if z > 0 and y==0:
                W[:2] -= learning_rate * x
                W[2] -= learning_rate    
        else:
            break

w1, w2, w0 = W

print("Optimal Weights", W)
print("Optimal inputs:",x)
# Out:
# Optimal Weights [-0.2990228367245853, 0.040519980938266795, 0.8499999999999999]
# Optimal inputs: [4.7 1.2]

# %%
# Equation of a line 
line_eqn = w1*x[0] + w2*x[1] + w0
print('equation of the line:',line_eqn)

# Finding slope and intercept
m= -(w1/w2)
c= -(w0/w2)
print('slope:',m)
print('intercept:',c)

# plot the graph using above slope equation
x_values = np.linspace(0, 6, 99)
y_values = m*x_values + c
# Out:
# equation of the line: -0.5067833554796308
# slope: 7.379639126191941
# intercept: -20.97730503118933

# %%
plt.figure(figsize=(10,10))
plt.plot(x_values,y_values,color="red",linewidth=2)
plt.scatter(x=df['petal_length'],y=df['petal_width'],c = df['species'])

plt.show()
